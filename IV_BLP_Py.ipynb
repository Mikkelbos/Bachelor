# %%
import pyblp
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import functions as fun
from linearmodels.iv import IV2SLS

pyblp.options.digits = 3
pyblp.options.verbose = False
pd.options.display.precision = 3
pd.options.display.max_columns = 50

import IPython.display
IPython.display.display(IPython.display.HTML('<style>pre { white-space: pre !important; }</style>'))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
df = pd.read_csv('dataset.csv')
Nobs=df['ID'].count()
df['Intercept']=np.ones((Nobs,1))
df.rename(columns={'Market share':'Market_share'}, inplace=True)
df2 = df[df['Market_share'] != 0]

df2.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range      Price   HP  \
# 8    1  2021     1.037e-02       Aiways         U5    400  2.846e+05  201
# 9    1  2022     5.976e-03       Aiways         U5    400  3.137e+05  201
# 10   1  2023     2.860e-03       Aiways         U5    400  2.645e+05  201
# 21   2  2023     4.848e-05       Aiways         U6    405  3.606e+05  214
# 28   3  2019     4.063e-02         Audi     e-tron    375  9.797e+05  402
# 29   3  2020     3.468e-02         Audi     e-tron    375  8.901e+05  402
# 30   3  2021     1.049e-02         Audi     e-tron    375  8.000e+05  402
# 31   3  2022     1.757e-02         Audi     e-tron    375  7.897e+05  402
# 32   3  2023     1.099e-03         Audi     e-tron    375  6.730e+05  402
# 41   4  2021     3.391e-03         Audi  e-tron GT    472  1.279e+06  522
# 42   4  2022     2.090e-03         Audi  e-tron GT    472  1.287e+06  522
# 43   4  2023     3.717e-04         Audi  e-tron GT    472  1.219e+06  522
# 52   5  2021     6.123e-02         Audi  Q4 e-tron    496  5.238e+05  281
# 53   5  2022     5.813e-02         Audi  Q4 e-tron    496  5.255e+05  281
# 54   5  2023     3.796e-02         Audi  Q4 e-tron    496  6.586e+05  281
# 65   6  2023     7.255e-03         Audi  Q8 e-tron    518  7.970e+05  335
# 66  10  2013     2.237e-03          BMW         I3    295  2.500e+05  167
# 67  10  2014     4.175e-02          BMW         I3    295  2.830e+05  167
# 68  10  2015     1.243e-01          BMW         I3    295  2.823e+05  167
# 69  10  2016     1.908e-01          BMW         I3    295  2.823e+05  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 8           34        SUV       C      CN    257        1.0
# 9           34        SUV       C      CN    183        1.0
# 10          34        SUV       C      CN    177        1.0
# 21          34        SUV       C      CN      3        1.0
# 28          17        SUV       F      DE    222        1.0
# 29          17        SUV       F      DE    491        1.0
# 30          17        SUV       F      DE    260        1.0
# 31          17        SUV       F      DE    538        1.0
# 32          17        SUV       F      DE     68        1.0
# 41          17      Sedan       F      DE     84        1.0
# 42          17      Sedan       F      DE     64        1.0
# 43          17      Sedan       F      DE     23        1.0
# 52          28        SUV       C      DE   1517        1.0
# 53          28        SUV       C      DE   1780        1.0
# 54          28        SUV       C      DE   2349        1.0
# 65          27        SUV       E      DE    449        1.0
# 66          18  Hatchback       B      DE      1        1.0
# 67          18  Hatchback       B      DE     62        1.0
# 68          18  Hatchback       B      DE    490        1.0
# 69          18  Hatchback       B      DE    227        1.0

# %%
# Copy the dataframe
data = df2.copy().reset_index(drop=True)
data.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range      Price   HP  \
# 0    1  2021     1.037e-02       Aiways         U5    400  2.846e+05  201
# 1    1  2022     5.976e-03       Aiways         U5    400  3.137e+05  201
# 2    1  2023     2.860e-03       Aiways         U5    400  2.645e+05  201
# 3    2  2023     4.848e-05       Aiways         U6    405  3.606e+05  214
# 4    3  2019     4.063e-02         Audi     e-tron    375  9.797e+05  402
# 5    3  2020     3.468e-02         Audi     e-tron    375  8.901e+05  402
# 6    3  2021     1.049e-02         Audi     e-tron    375  8.000e+05  402
# 7    3  2022     1.757e-02         Audi     e-tron    375  7.897e+05  402
# 8    3  2023     1.099e-03         Audi     e-tron    375  6.730e+05  402
# 9    4  2021     3.391e-03         Audi  e-tron GT    472  1.279e+06  522
# 10   4  2022     2.090e-03         Audi  e-tron GT    472  1.287e+06  522
# 11   4  2023     3.717e-04         Audi  e-tron GT    472  1.219e+06  522
# 12   5  2021     6.123e-02         Audi  Q4 e-tron    496  5.238e+05  281
# 13   5  2022     5.813e-02         Audi  Q4 e-tron    496  5.255e+05  281
# 14   5  2023     3.796e-02         Audi  Q4 e-tron    496  6.586e+05  281
# 15   6  2023     7.255e-03         Audi  Q8 e-tron    518  7.970e+05  335
# 16  10  2013     2.237e-03          BMW         I3    295  2.500e+05  167
# 17  10  2014     4.175e-02          BMW         I3    295  2.830e+05  167
# 18  10  2015     1.243e-01          BMW         I3    295  2.823e+05  167
# 19  10  2016     1.908e-01          BMW         I3    295  2.823e+05  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 0           34        SUV       C      CN    257        1.0
# 1           34        SUV       C      CN    183        1.0
# 2           34        SUV       C      CN    177        1.0
# 3           34        SUV       C      CN      3        1.0
# 4           17        SUV       F      DE    222        1.0
# 5           17        SUV       F      DE    491        1.0
# 6           17        SUV       F      DE    260        1.0
# 7           17        SUV       F      DE    538        1.0
# 8           17        SUV       F      DE     68        1.0
# 9           17      Sedan       F      DE     84        1.0
# 10          17      Sedan       F      DE     64        1.0
# 11          17      Sedan       F      DE     23        1.0
# 12          28        SUV       C      DE   1517        1.0
# 13          28        SUV       C      DE   1780        1.0
# 14          28        SUV       C      DE   2349        1.0
# 15          27        SUV       E      DE    449        1.0
# 16          18  Hatchback       B      DE      1        1.0
# 17          18  Hatchback       B      DE     62        1.0
# 18          18  Hatchback       B      DE    490        1.0
# 19          18  Hatchback       B      DE    227        1.0

# %%
fun.BLP(data, 'Range')
fun.BLP(data, 'HP')
fun.BLP(data, 'Chargetime')
# Out:
#       ID  Year  Market_share Manufacturer   Model  Range       Price   HP  \
# 0      1  2021     1.037e-02       Aiways      U5    400  284621.700  201
# 1      1  2022     5.976e-03       Aiways      U5    400  313681.829  201
# 2      1  2023     2.860e-03       Aiways      U5    400  264524.000  201
# 3      2  2023     4.848e-05       Aiways      U6    405  360638.000  214
# 4      3  2019     4.063e-02         Audi  e-tron    375  979704.475  402
# ..   ...   ...           ...          ...     ...    ...         ...  ...
# 329  189  2023     6.464e-05        Volvo    EX30    475  368245.000  268
# 330  190  2021     1.465e-02        Volvo    XC40    457  462060.600  402
# 331  190  2022     3.331e-02        Volvo    XC40    457  416263.400  402
# 332  190  2023     3.175e-02        Volvo    XC40    457  439266.600  402
# 333  192  2023     1.293e-04        Voyah    Free    500  504768.500  482
#
#      Chargetime Type Segment Country  Sales  Intercept  Range_BLP  HP_BLP  \
# 0            34  SUV       C      CN    257        1.0      21513   13583
# 1            34  SUV       C      CN    183        1.0      32180   20339
# 2            34  SUV       C      CN    177        1.0      41774   26403
# 3            34  SUV       C      CN      3        1.0      41769   26390
# 4            17  SUV       F      DE    222        1.0       5809    3901
# ..          ...  ...     ...     ...    ...        ...        ...     ...
# 329          28  SUV       B      SE      4        1.0      41699   26336
# 330          28  SUV       C      SE    363        1.0      21456   13382
# 331          28  SUV       C      SE   1020        1.0      32123   20138
# 332          28  SUV       C      SE   1965        1.0      41717   26202
# 333          55  SUV       E      CN      8        1.0      41674   26122
#
#      Chargetime_BLP
# 0              1861
# 1              2664
# 2              3241
# 3              3241
# 4               570
# ..              ...
# 329            3247
# 330            1867
# 331            2670
# 332            3247
# 333            3220
#
# [334 rows x 17 columns]

# %%
product_data = data.rename(columns={
    'Year': 'market_ids',
    'Model': 'product_ids',
    'Market_share': 'shares',
    'Price': 'prices',
    'Manufacturer': 'firm_ids',
    'Range_BLP': 'demand_instruments0',
    'HP_BLP': 'demand_instruments1',
    'Chargetime_BLP': 'demand_instruments2',
})

# %%
#Scale for better intepretation
product_data['prices'] = product_data['prices']/10_000 #(Change in ms(%) for change in pris in 10.000)
product_data['HP'] = product_data['HP']/10           #(Change in ms(%) for change in HP in 10)
product_data['Range'] = product_data['Range']/10     #(Change in ms(%) for change in rækkevidde in 10)

# %%
# Creating dummy for china
product_data['China'] = (product_data['Country'] == 'CN').astype(int)

# %% [markdown]
# # Outside share

# %%
product_data.loc[product_data['market_ids'] == 2013, 'shares'] = product_data.loc[product_data['market_ids'] == 2013, 'Sales'] / 180632
product_data.loc[product_data['market_ids'] == 2014, 'shares'] = product_data.loc[product_data['market_ids'] == 2014, 'Sales'] / 188406
product_data.loc[product_data['market_ids'] == 2015, 'shares'] = product_data.loc[product_data['market_ids'] == 2015, 'Sales'] / 206653
product_data.loc[product_data['market_ids'] == 2016, 'shares'] = product_data.loc[product_data['market_ids'] == 2016, 'Sales'] / 222471
product_data.loc[product_data['market_ids'] == 2017, 'shares'] = product_data.loc[product_data['market_ids'] == 2017, 'Sales'] / 221471
product_data.loc[product_data['market_ids'] == 2018, 'shares'] = product_data.loc[product_data['market_ids'] == 2018, 'Sales'] / 252328
product_data.loc[product_data['market_ids'] == 2019, 'shares'] = product_data.loc[product_data['market_ids'] == 2019, 'Sales'] / 258727
product_data.loc[product_data['market_ids'] == 2020, 'shares'] = product_data.loc[product_data['market_ids'] == 2020, 'Sales'] / 230060
product_data.loc[product_data['market_ids'] == 2021, 'shares'] = product_data.loc[product_data['market_ids'] == 2021, 'Sales'] / 222210
product_data.loc[product_data['market_ids'] == 2022, 'shares'] = product_data.loc[product_data['market_ids'] == 2022, 'Sales'] / 181030
product_data.loc[product_data['market_ids'] == 2023, 'shares'] = product_data.loc[product_data['market_ids'] == 2023, 'Sales'] / 203690

# %%
product_data['outside_share'] = 1 - product_data.groupby('market_ids')['shares'].transform('sum')
product_data[['shares', 'outside_share']].describe()
# Out:
#           shares  outside_share
# count  3.340e+02        334.000
# mean   2.128e-03          0.841
# std    5.618e-03          0.109
# min    4.347e-06          0.696
# 25%    1.227e-04          0.696
# 50%    7.149e-04          0.831
# 75%    2.161e-03          0.938
# max    8.814e-02          0.998

# %% [markdown]
# # Demand

# %%
product_data['logit_delta'] = np.log(product_data['shares'] / product_data['outside_share'])
formula = 'logit_delta ~ 1 + [prices ~ demand_instruments0 + demand_instruments1 + demand_instruments2] + Range + HP + Chargetime + China'
IV = IV2SLS.from_formula(formula, product_data).fit(cov_type='robust')
IV.first_stage
# Out:
#     First Stage Estimation Results
# ======================================
#                                 prices
# --------------------------------------
# R-squared                       0.5822
# Partial R-squared               0.0261
# Shea's R-squared                0.0261
# Partial F-statistic             17.145
# P-value (Partial F-stat)        0.0007
# Partial F-stat Distn           chi2(3)
# ========================== ===========
# Intercept                      -1.3281
#                              (-0.1735)
# Range                           0.1875
#                               (0.9233)
# HP                              1.3688
#                               (10.566)
# Chargetime                     -0.1573
#                              (-2.1043)
# China                          -13.513
#                              (-5.4358)
# demand_instruments0            -0.0154
#                              (-2.4934)
# demand_instruments1             0.0212
#                               (2.3603)
# demand_instruments2             0.0308
#                               (2.1001)
# --------------------------------------
#
# T-stats reported in parentheses
# T-stats use same covariance type as original model
# FirstStageResults, id: 0x7fe3ed41aa00

# %%
IV.summary#.tables[1]
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            logit_delta   R-squared:                      0.1614
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1486
# No. Observations:                 334   F-statistic:                    101.16
# Date:                Mon, Jun 03 2024   P-value (F-stat)                0.0000
# Time:                        22:36:38   Distribution:                  chi2(5)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -9.0442     0.7141    -12.665     0.0000     -10.444     -7.6446
# Range          0.0979     0.0207     4.7296     0.0000      0.0573      0.1384
# HP            -0.0687     0.0370    -1.8581     0.0632     -0.1412      0.0038
# Chargetime    -0.0313     0.0117    -2.6686     0.0076     -0.0543     -0.0083
# China         -0.5112     0.4488    -1.1391     0.2547     -1.3908      0.3684
# prices         0.0121     0.0324     0.3734     0.7089     -0.0514      0.0757
# ==============================================================================
#
# Endogenous: prices
# Instruments: demand_instruments0, demand_instruments1, demand_instruments2
# Robust Covariance (Heteroskedastic)
# Debiased: False
# """

# %%
BLP_problem = pyblp.Problem(pyblp.Formulation('1 + prices + Range + HP + Chargetime + China'), product_data)
BLP_results = BLP_problem.solve(method='1s')

# %%
data2023 = product_data[product_data['market_ids'] == 2023]
ols_elasticities = BLP_results.compute_elasticities(market_id=2023) # name = 'Range' for elasticities of Range
pd.DataFrame(ols_elasticities, index = data2023['product_ids'], columns=data2023['product_ids'])
# Out:
# product_ids         U5         U6     e-tron  e-tron GT  Q4 e-tron  Q8 e-tron  \
# product_ids
# U5           3.200e-01 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
# U6          -2.783e-04  4.366e-01 -2.720e-04 -1.667e-04     -0.009     -0.002
# e-tron      -2.783e-04 -6.430e-06  8.145e-01 -1.667e-04     -0.009     -0.002
# e-tron GT   -2.783e-04 -6.430e-06 -2.720e-04  1.476e+00     -0.009     -0.002
# Q4 e-tron   -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04      0.788     -0.002
# ...                ...        ...        ...        ...        ...        ...
# up!         -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
# C40         -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
# EX30        -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
# XC40        -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
# Free        -2.783e-04 -6.430e-06 -2.720e-04 -1.667e-04     -0.009     -0.002
#
# product_ids         I3     i4     i5         I7     iX    iX1    iX3  \
# product_ids
# U5          -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# U6          -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# e-tron      -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# e-tron GT   -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# Q4 e-tron   -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# ...                ...    ...    ...        ...    ...    ...    ...
# up!         -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# C40         -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# EX30        -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# XC40        -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
# Free        -1.883e-06 -0.006 -0.002 -4.656e-04 -0.002 -0.003 -0.003
#
# product_ids     Atto 3    Dolphin        Han       Seal       Tang   Berlingo  \
# product_ids
# U5          -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# U6          -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# e-tron      -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# e-tron GT   -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# Q4 e-tron   -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# ...                ...        ...        ...        ...        ...        ...
# up!         -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# C40         -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# EX30        -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# XC40        -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
# Free        -4.090e-04 -2.814e-04 -1.053e-05 -6.098e-05 -1.665e-05 -5.051e-05
#
# product_ids         C4     ë-C4 X  e-SpaceTourer      Jumpy   Born     Spring  \
# product_ids
# U5          -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# U6          -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# e-tron      -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# e-tron GT   -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# Q4 e-tron   -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# ...                ...        ...            ...        ...    ...        ...
# up!         -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# C40         -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# EX30        -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# XC40        -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
# Free        -3.676e-04 -3.206e-04     -1.100e-04 -1.701e-05 -0.003 -8.506e-05
#
# product_ids  ...  Taycan  Megane        Zoe  Enyaq iV     Fortwo    Korando  \
# product_ids  ...
# U5           ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# U6           ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# e-tron       ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# e-tron GT    ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# Q4 e-tron    ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# ...          ...     ...     ...        ...       ...        ...        ...
# up!          ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# C40          ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# EX30         ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# XC40         ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
# Free         ...  -0.001  -0.002 -4.530e-05    -0.008 -3.753e-06 -6.783e-06
#
# product_ids   Solterra  Model 3    Model S    Model X  Model Y   bZ4X  \
# product_ids
# U5          -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# U6          -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# e-tron      -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# e-tron GT   -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# Q4 e-tron   -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# ...                ...      ...        ...        ...      ...    ...
# up!         -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# C40         -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# EX30        -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# XC40        -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
# Free        -1.124e-04   -0.009 -7.528e-04 -4.429e-04   -0.043 -0.002
#
# product_ids  Proace City Verso  Proace Verso       Golf   ID.3   ID.4   ID.5  \
# product_ids
# U5                  -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# U6                  -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# e-tron              -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# e-tron GT           -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# Q4 e-tron           -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# ...                        ...           ...        ...    ...    ...    ...
# up!                 -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# C40                 -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# EX30                -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# XC40                -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
# Free                -1.754e-05    -4.941e-05 -1.857e-06 -0.002 -0.006 -0.002
#
# product_ids       ID.7  ID.Buzz        up!    C40       EX30   XC40       Free
# product_ids
# U5          -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005 -2.400e-05
# U6          -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005 -2.400e-05
# e-tron      -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005 -2.400e-05
# e-tron GT   -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005 -2.400e-05
# Q4 e-tron   -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005 -2.400e-05
# ...                ...      ...        ...    ...        ...    ...        ...
# up!         -5.787e-04   -0.004  2.116e-01 -0.001 -8.755e-06 -0.005 -2.400e-05
# C40         -5.787e-04   -0.004 -8.210e-05  0.520 -8.755e-06 -0.005 -2.400e-05
# EX30        -5.787e-04   -0.004 -8.210e-05 -0.001  4.458e-01 -0.005 -2.400e-05
# XC40        -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06  0.527 -2.400e-05
# Free        -5.787e-04   -0.004 -8.210e-05 -0.001 -8.755e-06 -0.005  6.111e-01
#
# [100 rows x 100 columns]

# %% [markdown]
# # Cost

# %%
product_data['costs'] = BLP_results.compute_costs()
product_data['profit_per_car'] = product_data['prices'] - product_data['costs']
product_data['markups'] = product_data['profit_per_car'] / product_data['costs']
product_data['profits'] = BLP_results.compute_profits()
product_data[['prices', 'costs', 'profit_per_car', 'markups', 'profits']].describe()
# Out:
#         prices    costs  profit_per_car  markups    profits
# count  334.000  334.000         334.000  334.000  3.340e+02
# mean    46.911  130.133         -83.222   -0.665 -1.809e-01
# std     29.975   30.272           1.233    0.115  5.098e-01
# min     12.486   95.191         -92.772   -0.869 -8.177e+00
# 25%     28.398  111.138         -83.418   -0.744 -1.792e-01
# 50%     35.904  119.248         -82.794   -0.698 -5.952e-02
# 75%     52.962  137.283         -82.662   -0.614 -1.015e-02
# max    194.052  277.612         -82.602   -0.301 -3.590e-04

# %%
product_data.loc[product_data['market_ids'] == 2023]
# Out:
#       ID  market_ids     shares    firm_ids product_ids  Range   prices    HP  \
# 2      1        2023  8.690e-04      Aiways          U5   40.0   26.452  20.1
# 3      2        2023  1.473e-05      Aiways          U6   40.5   36.064  21.4
# 8      3        2023  3.338e-04        Audi      e-tron   37.5   67.304  40.2
# 11     4        2023  1.129e-04        Audi   e-tron GT   47.2  121.934  52.2
# 14     5        2023  1.153e-02        Audi   Q4 e-tron   49.6   65.855  28.1
# ..   ...         ...        ...         ...         ...    ...      ...   ...
# 325  187        2023  3.878e-04  Volkswagen         up!   25.6   17.485   8.1
# 328  188        2023  2.538e-03       Volvo         C40   46.6   43.066  40.2
# 329  189        2023  1.964e-05       Volvo        EX30   47.5   36.825  26.8
# 332  190        2023  9.647e-03       Volvo        XC40   45.7   43.927  40.2
# 333  192        2023  3.928e-05       Voyah        Free   50.0   50.477  48.2
#
#      Chargetime       Type Segment Country  Sales  Intercept  \
# 2            34        SUV       C      CN    177        1.0
# 3            34        SUV       C      CN      3        1.0
# 8            17        SUV       F      DE     68        1.0
# 11           17      Sedan       F      DE     23        1.0
# 14           28        SUV       C      DE   2349        1.0
# ..          ...        ...     ...     ...    ...        ...
# 325          48  Hatchback       A      DE     79        1.0
# 328          28        SUV       C      SE    517        1.0
# 329          28        SUV       B      SE      4        1.0
# 332          28        SUV       C      SE   1965        1.0
# 333          55        SUV       E      CN      8        1.0
#
#      demand_instruments0  demand_instruments1  demand_instruments2  China  \
# 2                  41774                26403                 3241      1
# 3                  41769                26390                 3241      1
# 8                  41799                26202                 3258      0
# 11                 41702                26082                 3258      0
# 14                 41678                26323                 3247      0
# ..                   ...                  ...                  ...    ...
# 325                41918                26523                 3227      0
# 328                41708                26202                 3247      0
# 329                41699                26336                 3247      0
# 332                41717                26202                 3247      0
# 333                41674                26122                 3220      1
#
#      outside_share  logit_delta    costs  profit_per_car  markups  profits
# 2            0.696       -6.686  109.127         -82.675   -0.758   -0.072
# 3            0.696      -10.764  118.739         -82.675   -0.696   -0.001
# 8            0.696       -7.643  151.094         -83.790   -0.555   -0.028
# 11           0.696       -8.727  205.724         -83.790   -0.407   -0.009
# 14           0.696       -4.100  149.645         -83.790   -0.560   -0.966
# ..             ...          ...      ...             ...      ...      ...
# 325          0.696       -7.493  102.668         -85.182   -0.830   -0.033
# 328          0.696       -5.614  126.689         -83.622   -0.660   -0.212
# 329          0.696      -10.476  120.447         -83.622   -0.694   -0.002
# 332          0.696       -4.279  127.549         -83.622   -0.656   -0.807
# 333          0.696       -9.783  133.082         -82.605   -0.621   -0.003
#
# [100 rows x 24 columns]

# %%
statsmodels_ols = smf.ols('np.log(costs) ~ 1 + Range + HP + Chargetime', product_data)
statsmodels_results = statsmodels_ols.fit(cov_type='HC0')
statsmodels_results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.629
# Dependent Variable: np.log(costs)    AIC:                -453.9122
# Date:               2024-06-03 22:36 BIC:                -438.6676
# No. Observations:   334              Log-Likelihood:     230.96
# Df Model:           3                F-statistic:        148.5
# Df Residuals:       330              Prob (F-statistic): 6.61e-61
# R-squared:          0.633            Scale:              0.014864
# -------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept      4.6204    0.0378  122.2682  0.0000   4.5463   4.6944
# Range          0.0030    0.0011    2.6468  0.0081   0.0008   0.0052
# HP             0.0076    0.0006   11.9383  0.0000   0.0064   0.0089
# Chargetime    -0.0025    0.0005   -4.6577  0.0000  -0.0035  -0.0014
# ------------------------------------------------------------------
# Omnibus:             123.931       Durbin-Watson:          0.601
# Prob(Omnibus):       0.000         Jarque-Bera (JB):       441.283
# Skew:                1.626         Prob(JB):               0.000
# Kurtosis:            7.597         Condition No.:          333
# ==================================================================
#
# """

# %%
eq_prices = BLP_results.compute_prices()
product_data['eq_prices'] = eq_prices
prices = pd.DataFrame(eq_prices, index = product_data['product_ids'])

# %%
prices.loc['Model Y']
# Out:
#                   0
# product_ids
# Model Y      50.324
# Model Y      52.115
# Model Y      40.555
