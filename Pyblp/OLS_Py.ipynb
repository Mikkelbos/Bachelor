# %%
import pyblp
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import functions as fun

pyblp.options.digits = 3
pyblp.options.verbose = False
pd.options.display.precision = 3
pd.options.display.max_columns = 50

import IPython.display
IPython.display.display(IPython.display.HTML('<style>pre { white-space: pre !important; }</style>'))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
df = pd.read_csv('dataset.csv')
Nobs=df['ID'].count()
df['Intercept']=np.ones((Nobs,1))
df.rename(columns={'Market share':'Market_share'}, inplace=True)
df2 = df[df['Market_share'] != 0]

df2.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range      Price   HP  \
# 8    1  2021     1.037e-02       Aiways         U5    400  2.846e+05  201
# 9    1  2022     5.976e-03       Aiways         U5    400  3.137e+05  201
# 10   1  2023     2.860e-03       Aiways         U5    400  2.645e+05  201
# 21   2  2023     4.848e-05       Aiways         U6    405  3.606e+05  214
# 28   3  2019     4.063e-02         Audi     e-tron    375  9.797e+05  402
# 29   3  2020     3.468e-02         Audi     e-tron    375  8.901e+05  402
# 30   3  2021     1.049e-02         Audi     e-tron    375  8.000e+05  402
# 31   3  2022     1.757e-02         Audi     e-tron    375  7.897e+05  402
# 32   3  2023     1.099e-03         Audi     e-tron    375  6.730e+05  402
# 41   4  2021     3.391e-03         Audi  e-tron GT    472  1.279e+06  522
# 42   4  2022     2.090e-03         Audi  e-tron GT    472  1.287e+06  522
# 43   4  2023     3.717e-04         Audi  e-tron GT    472  1.219e+06  522
# 52   5  2021     6.123e-02         Audi  Q4 e-tron    496  5.238e+05  281
# 53   5  2022     5.813e-02         Audi  Q4 e-tron    496  5.255e+05  281
# 54   5  2023     3.796e-02         Audi  Q4 e-tron    496  6.586e+05  281
# 65   6  2023     7.255e-03         Audi  Q8 e-tron    518  7.970e+05  335
# 66  10  2013     2.237e-03          BMW         I3    295  2.500e+05  167
# 67  10  2014     4.175e-02          BMW         I3    295  2.830e+05  167
# 68  10  2015     1.243e-01          BMW         I3    295  2.823e+05  167
# 69  10  2016     1.908e-01          BMW         I3    295  2.823e+05  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 8           34        SUV       C      CN    257        1.0
# 9           34        SUV       C      CN    183        1.0
# 10          34        SUV       C      CN    177        1.0
# 21          34        SUV       C      CN      3        1.0
# 28          17        SUV       F      DE    222        1.0
# 29          17        SUV       F      DE    491        1.0
# 30          17        SUV       F      DE    260        1.0
# 31          17        SUV       F      DE    538        1.0
# 32          17        SUV       F      DE     68        1.0
# 41          17      Sedan       F      DE     84        1.0
# 42          17      Sedan       F      DE     64        1.0
# 43          17      Sedan       F      DE     23        1.0
# 52          28        SUV       C      DE   1517        1.0
# 53          28        SUV       C      DE   1780        1.0
# 54          28        SUV       C      DE   2349        1.0
# 65          27        SUV       E      DE    449        1.0
# 66          18  Hatchback       B      DE      1        1.0
# 67          18  Hatchback       B      DE     62        1.0
# 68          18  Hatchback       B      DE    490        1.0
# 69          18  Hatchback       B      DE    227        1.0

# %%
# Copy the dataframe
data = df2.copy().reset_index(drop=True)
data.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range      Price   HP  \
# 0    1  2021     1.037e-02       Aiways         U5    400  2.846e+05  201
# 1    1  2022     5.976e-03       Aiways         U5    400  3.137e+05  201
# 2    1  2023     2.860e-03       Aiways         U5    400  2.645e+05  201
# 3    2  2023     4.848e-05       Aiways         U6    405  3.606e+05  214
# 4    3  2019     4.063e-02         Audi     e-tron    375  9.797e+05  402
# 5    3  2020     3.468e-02         Audi     e-tron    375  8.901e+05  402
# 6    3  2021     1.049e-02         Audi     e-tron    375  8.000e+05  402
# 7    3  2022     1.757e-02         Audi     e-tron    375  7.897e+05  402
# 8    3  2023     1.099e-03         Audi     e-tron    375  6.730e+05  402
# 9    4  2021     3.391e-03         Audi  e-tron GT    472  1.279e+06  522
# 10   4  2022     2.090e-03         Audi  e-tron GT    472  1.287e+06  522
# 11   4  2023     3.717e-04         Audi  e-tron GT    472  1.219e+06  522
# 12   5  2021     6.123e-02         Audi  Q4 e-tron    496  5.238e+05  281
# 13   5  2022     5.813e-02         Audi  Q4 e-tron    496  5.255e+05  281
# 14   5  2023     3.796e-02         Audi  Q4 e-tron    496  6.586e+05  281
# 15   6  2023     7.255e-03         Audi  Q8 e-tron    518  7.970e+05  335
# 16  10  2013     2.237e-03          BMW         I3    295  2.500e+05  167
# 17  10  2014     4.175e-02          BMW         I3    295  2.830e+05  167
# 18  10  2015     1.243e-01          BMW         I3    295  2.823e+05  167
# 19  10  2016     1.908e-01          BMW         I3    295  2.823e+05  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 0           34        SUV       C      CN    257        1.0
# 1           34        SUV       C      CN    183        1.0
# 2           34        SUV       C      CN    177        1.0
# 3           34        SUV       C      CN      3        1.0
# 4           17        SUV       F      DE    222        1.0
# 5           17        SUV       F      DE    491        1.0
# 6           17        SUV       F      DE    260        1.0
# 7           17        SUV       F      DE    538        1.0
# 8           17        SUV       F      DE     68        1.0
# 9           17      Sedan       F      DE     84        1.0
# 10          17      Sedan       F      DE     64        1.0
# 11          17      Sedan       F      DE     23        1.0
# 12          28        SUV       C      DE   1517        1.0
# 13          28        SUV       C      DE   1780        1.0
# 14          28        SUV       C      DE   2349        1.0
# 15          27        SUV       E      DE    449        1.0
# 16          18  Hatchback       B      DE      1        1.0
# 17          18  Hatchback       B      DE     62        1.0
# 18          18  Hatchback       B      DE    490        1.0
# 19          18  Hatchback       B      DE    227        1.0

# %%
product_data = data.rename(columns={
    'Year': 'market_ids',
    'Model': 'product_ids',
    'Market_share': 'shares',
    'Price': 'prices',
    'Manufacturer': 'firm_ids',
})

# %%
#Scale for better intepretation
product_data['prices'] = product_data['prices']/10_000 #(Change in ms(%) for change in pris in 10.000)
product_data['HP'] = product_data['HP']/10           #(Change in ms(%) for change in HP in 10)
product_data['Range'] = product_data['Range']/10     #(Change in ms(%) for change in rækkevidde in 10)

# %%
# Creating dummy for china
product_data['China'] = (product_data['Country'] == 'CN').astype(int)

# %% [markdown]
# # Outside share

# %%
product_data.loc[product_data['market_ids'] == 2013, 'shares'] = product_data.loc[product_data['market_ids'] == 2013, 'Sales'] / 180632
product_data.loc[product_data['market_ids'] == 2014, 'shares'] = product_data.loc[product_data['market_ids'] == 2014, 'Sales'] / 188406
product_data.loc[product_data['market_ids'] == 2015, 'shares'] = product_data.loc[product_data['market_ids'] == 2015, 'Sales'] / 206653
product_data.loc[product_data['market_ids'] == 2016, 'shares'] = product_data.loc[product_data['market_ids'] == 2016, 'Sales'] / 222471
product_data.loc[product_data['market_ids'] == 2017, 'shares'] = product_data.loc[product_data['market_ids'] == 2017, 'Sales'] / 221471
product_data.loc[product_data['market_ids'] == 2018, 'shares'] = product_data.loc[product_data['market_ids'] == 2018, 'Sales'] / 252328
product_data.loc[product_data['market_ids'] == 2019, 'shares'] = product_data.loc[product_data['market_ids'] == 2019, 'Sales'] / 258727
product_data.loc[product_data['market_ids'] == 2020, 'shares'] = product_data.loc[product_data['market_ids'] == 2020, 'Sales'] / 230060
product_data.loc[product_data['market_ids'] == 2021, 'shares'] = product_data.loc[product_data['market_ids'] == 2021, 'Sales'] / 222210
product_data.loc[product_data['market_ids'] == 2022, 'shares'] = product_data.loc[product_data['market_ids'] == 2022, 'Sales'] / 181030
product_data.loc[product_data['market_ids'] == 2023, 'shares'] = product_data.loc[product_data['market_ids'] == 2023, 'Sales'] / 203690

# %%
product_data['outside_share'] = 1 - product_data.groupby('market_ids')['shares'].transform('sum')
product_data[['shares', 'outside_share']].describe()
# Out:
#           shares  outside_share
# count  3.340e+02        334.000
# mean   2.128e-03          0.841
# std    5.618e-03          0.109
# min    4.347e-06          0.696
# 25%    1.227e-04          0.696
# 50%    7.149e-04          0.831
# 75%    2.161e-03          0.938
# max    8.814e-02          0.998

# %% [markdown]
# # Demand

# %%
product_data['logit_delta'] = np.log(product_data['shares'] / product_data['outside_share'])
statsmodels_ols = smf.ols('logit_delta ~ 1 + prices + Range + HP + Chargetime + China', product_data)
statsmodels_results = statsmodels_ols.fit(cov_type='HC0')
statsmodels_results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.271
# Dependent Variable: logit_delta      AIC:                1327.0275
# Date:               2024-06-03 22:30 BIC:                1349.8944
# No. Observations:   334              Log-Likelihood:     -657.51
# Df Model:           5                F-statistic:        36.87
# Df Residuals:       328              Prob (F-statistic): 6.05e-30
# R-squared:          0.282            Scale:              3.0571
# -------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept     -8.5912    0.5798  -14.8186  0.0000  -9.7275  -7.4549
# prices        -0.0242    0.0047   -5.1051  0.0000  -0.0335  -0.0149
# Range          0.1124    0.0124    9.0616  0.0000   0.0881   0.1367
# HP            -0.0280    0.0110   -2.5465  0.0109  -0.0496  -0.0065
# Chargetime    -0.0402    0.0089   -4.5286  0.0000  -0.0577  -0.0228
# China         -0.9174    0.2973   -3.0863  0.0020  -1.5000  -0.3348
# ------------------------------------------------------------------
# Omnibus:               38.751       Durbin-Watson:          1.337
# Prob(Omnibus):         0.000        Jarque-Bera (JB):       48.788
# Skew:                  -0.882       Prob(JB):               0.000
# Kurtosis:              3.630        Condition No.:          450
# ==================================================================
#
# """

# %%
product_data['demand_instruments0'] = product_data['prices']
ols_problem = pyblp.Problem(pyblp.Formulation('1 + prices + Range + HP + Chargetime + China'), product_data)
ols_results = ols_problem.solve(method='1s')

# %%
data2023 = product_data[product_data['market_ids'] == 2023]
ols_elasticities = ols_results.compute_elasticities(market_id=2023) # name = 'Range' for elasticities of Range
pd.DataFrame(ols_elasticities, index = data2023['product_ids'], columns=data2023['product_ids'])
# Out:
# product_ids         U5         U6     e-tron  e-tron GT  Q4 e-tron  Q8 e-tron  \
# product_ids
# U5          -6.391e-01  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
# U6           5.558e-04 -8.720e-01  5.433e-04  3.329e-04      0.018      0.004
# e-tron       5.558e-04  1.284e-05 -1.627e+00  3.329e-04      0.018      0.004
# e-tron GT    5.558e-04  1.284e-05  5.433e-04 -2.948e+00      0.018      0.004
# Q4 e-tron    5.558e-04  1.284e-05  5.433e-04  3.329e-04     -1.574      0.004
# ...                ...        ...        ...        ...        ...        ...
# up!          5.558e-04  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
# C40          5.558e-04  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
# EX30         5.558e-04  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
# XC40         5.558e-04  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
# Free         5.558e-04  1.284e-05  5.433e-04  3.329e-04      0.018      0.004
#
# product_ids         I3     i4     i5         I7     iX    iX1    iX3  \
# product_ids
# U5           3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# U6           3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# e-tron       3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# e-tron GT    3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# Q4 e-tron    3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# ...                ...    ...    ...        ...    ...    ...    ...
# up!          3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# C40          3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# EX30         3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# XC40         3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
# Free         3.761e-06  0.012  0.003  9.300e-04  0.005  0.006  0.006
#
# product_ids     Atto 3    Dolphin        Han       Seal       Tang   Berlingo  \
# product_ids
# U5           8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# U6           8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# e-tron       8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# e-tron GT    8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# Q4 e-tron    8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# ...                ...        ...        ...        ...        ...        ...
# up!          8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# C40          8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# EX30         8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# XC40         8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
# Free         8.170e-04  5.621e-04  2.103e-05  1.218e-04  3.325e-05  1.009e-04
#
# product_ids         C4     ë-C4 X  e-SpaceTourer      Jumpy   Born     Spring  \
# product_ids
# U5           7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# U6           7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# e-tron       7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# e-tron GT    7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# Q4 e-tron    7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# ...                ...        ...            ...        ...    ...        ...
# up!          7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# C40          7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# EX30         7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# XC40         7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
# Free         7.343e-04  6.403e-04      2.197e-04  3.398e-05  0.005  1.699e-04
#
# product_ids  ...  Taycan  Megane        Zoe  Enyaq iV     Fortwo    Korando  \
# product_ids  ...
# U5           ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# U6           ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# e-tron       ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# e-tron GT    ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# Q4 e-tron    ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# ...          ...     ...     ...        ...       ...        ...        ...
# up!          ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# C40          ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# EX30         ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# XC40         ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
# Free         ...   0.002   0.005  9.047e-05     0.016  7.495e-06  1.355e-05
#
# product_ids   Solterra  Model 3  Model S    Model X  Model Y   bZ4X  \
# product_ids
# U5           2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# U6           2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# e-tron       2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# e-tron GT    2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# Q4 e-tron    2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# ...                ...      ...      ...        ...      ...    ...
# up!          2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# C40          2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# EX30         2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# XC40         2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
# Free         2.244e-04    0.018    0.002  8.845e-04    0.086  0.005
#
# product_ids  Proace City Verso  Proace Verso       Golf   ID.3   ID.4   ID.5  \
# product_ids
# U5                   3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# U6                   3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# e-tron               3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# e-tron GT            3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# Q4 e-tron            3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# ...                        ...           ...        ...    ...    ...    ...
# up!                  3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# C40                  3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# EX30                 3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# XC40                 3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
# Free                 3.503e-05     9.869e-05  3.710e-06  0.005  0.013  0.005
#
# product_ids   ID.7  ID.Buzz        up!    C40       EX30   XC40       Free
# product_ids
# U5           0.001    0.008  1.640e-04  0.003  1.749e-05  0.010  4.794e-05
# U6           0.001    0.008  1.640e-04  0.003  1.749e-05  0.010  4.794e-05
# e-tron       0.001    0.008  1.640e-04  0.003  1.749e-05  0.010  4.794e-05
# e-tron GT    0.001    0.008  1.640e-04  0.003  1.749e-05  0.010  4.794e-05
# Q4 e-tron    0.001    0.008  1.640e-04  0.003  1.749e-05  0.010  4.794e-05
# ...            ...      ...        ...    ...        ...    ...        ...
# up!          0.001    0.008 -4.226e-01  0.003  1.749e-05  0.010  4.794e-05
# C40          0.001    0.008  1.640e-04 -1.039  1.749e-05  0.010  4.794e-05
# EX30         0.001    0.008  1.640e-04  0.003 -8.904e-01  0.010  4.794e-05
# XC40         0.001    0.008  1.640e-04  0.003  1.749e-05 -1.052  4.794e-05
# Free         0.001    0.008  1.640e-04  0.003  1.749e-05  0.010 -1.220e+00
#
# [100 rows x 100 columns]

# %% [markdown]
# # Cost

# %%
product_data['costs'] = ols_results.compute_costs()
product_data['profit_per_car'] = product_data['prices'] - product_data['costs']
product_data['markups'] = product_data['profit_per_car'] / product_data['costs']
product_data['profits'] = ols_results.compute_profits()
product_data[['prices', 'costs', 'profit_per_car', 'markups', 'profits']].describe()
# Out:
#         prices    costs  profit_per_car   markups    profits
# count  334.000  334.000         334.000   334.000  3.340e+02
# mean    46.911    5.244          41.667    -3.174  9.056e-02
# std     29.975   29.843           0.617    81.237  2.552e-01
# min     12.486  -28.921          41.356 -1269.846  1.798e-04
# 25%     28.398  -13.004          41.386    -3.977  5.084e-03
# 50%     35.904   -5.711          41.453    -2.269  2.980e-02
# 75%     52.962   10.773          41.765     1.240  8.970e-02
# max    194.052  152.217          46.448   668.759  4.094e+00

# %%
product_data.loc[product_data['market_ids'] == 2023]
# Out:
#       ID  market_ids     shares    firm_ids product_ids  Range   prices    HP  \
# 2      1        2023  8.690e-04      Aiways          U5   40.0   26.452  20.1
# 3      2        2023  1.473e-05      Aiways          U6   40.5   36.064  21.4
# 8      3        2023  3.338e-04        Audi      e-tron   37.5   67.304  40.2
# 11     4        2023  1.129e-04        Audi   e-tron GT   47.2  121.934  52.2
# 14     5        2023  1.153e-02        Audi   Q4 e-tron   49.6   65.855  28.1
# ..   ...         ...        ...         ...         ...    ...      ...   ...
# 325  187        2023  3.878e-04  Volkswagen         up!   25.6   17.485   8.1
# 328  188        2023  2.538e-03       Volvo         C40   46.6   43.066  40.2
# 329  189        2023  1.964e-05       Volvo        EX30   47.5   36.825  26.8
# 332  190        2023  9.647e-03       Volvo        XC40   45.7   43.927  40.2
# 333  192        2023  3.928e-05       Voyah        Free   50.0   50.477  48.2
#
#      Chargetime       Type Segment Country  Sales  Intercept  China  \
# 2            34        SUV       C      CN    177        1.0      1
# 3            34        SUV       C      CN      3        1.0      1
# 8            17        SUV       F      DE     68        1.0      0
# 11           17      Sedan       F      DE     23        1.0      0
# 14           28        SUV       C      DE   2349        1.0      0
# ..          ...        ...     ...     ...    ...        ...    ...
# 325          48  Hatchback       A      DE     79        1.0      0
# 328          28        SUV       C      SE    517        1.0      0
# 329          28        SUV       B      SE      4        1.0      0
# 332          28        SUV       C      SE   1965        1.0      0
# 333          55        SUV       E      CN      8        1.0      1
#
#      outside_share  logit_delta  demand_instruments0   costs  profit_per_car  \
# 2            0.696       -6.686               26.452 -14.940          41.393
# 3            0.696      -10.764               36.064  -5.329          41.393
# 8            0.696       -7.643               67.304  25.353          41.951
# 11           0.696       -8.727              121.934  79.983          41.951
# 14           0.696       -4.100               65.855  23.904          41.951
# ..             ...          ...                  ...     ...             ...
# 325          0.696       -7.493               17.485 -25.163          42.648
# 328          0.696       -5.614               43.066   1.199          41.867
# 329          0.696      -10.476               36.825  -5.043          41.867
# 332          0.696       -4.279               43.927   2.060          41.867
# 333          0.696       -9.783               50.477   9.119          41.358
#
#      markups    profits
# 2     -2.771  3.597e-02
# 3     -7.768  6.096e-04
# 8      1.655  1.400e-02
# 11     0.524  4.737e-03
# 14     1.755  4.838e-01
# ..       ...        ...
# 325   -1.695  1.654e-02
# 328   34.906  1.063e-01
# 329   -8.303  8.222e-04
# 332   20.328  4.039e-01
# 333    4.535  1.624e-03
#
# [100 rows x 22 columns]

# %%
statsmodels_ols = smf.ols('np.log(costs) ~ 1 + Range + HP + Chargetime', product_data)
statsmodels_results = statsmodels_ols.fit(cov_type='HC0')
statsmodels_results.summary2()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.287
# Dependent Variable: np.log(costs)    AIC:                452.2549
# Date:               2024-06-03 22:30 BIC:                463.8463
# No. Observations:   134              Log-Likelihood:     -222.13
# Df Model:           3                F-statistic:        35.62
# Df Residuals:       130              Prob (F-statistic): 7.20e-17
# R-squared:          0.303            Scale:              1.6616
# ------------------------------------------------------------------
#                 Coef.   Std.Err.     z     P>|z|    [0.025  0.975]
# ------------------------------------------------------------------
# Intercept       0.3940    0.9168   0.4298  0.6674  -1.4029  2.1909
# Range          -0.0004    0.0167  -0.0239  0.9809  -0.0332  0.0324
# HP              0.0502    0.0064   7.8001  0.0000   0.0376  0.0628
# Chargetime      0.0112    0.0148   0.7534  0.4512  -0.0179  0.0402
# -----------------------------------------------------------------
# Omnibus:               6.286        Durbin-Watson:          0.882
# Prob(Omnibus):         0.043        Jarque-Bera (JB):       5.840
# Skew:                  -0.486       Prob(JB):               0.054
# Kurtosis:              3.317        Condition No.:          483
# =================================================================
#
# """

# %%
eq_prices = ols_results.compute_prices()
prices = pd.DataFrame(eq_prices, index = product_data['product_ids'])

# %%
prices.loc['Model Y']
# Out:
#                   0
# product_ids
# Model Y      50.324
# Model Y      52.115
# Model Y      40.555

# %%
product_data[product_data['product_ids'] == 'Model Y']
# Out:
#       ID  market_ids  shares firm_ids product_ids  Range  prices    HP  \
# 283  175        2021   0.007    Tesla     Model Y   50.6  50.324  50.6
# 284  175        2022   0.013    Tesla     Model Y   50.6  52.115  50.6
# 285  175        2023   0.088    Tesla     Model Y   50.6  40.555  50.6
#
#      Chargetime Type Segment Country  Sales  Intercept  China  outside_share  \
# 283          27  SUV       D      US   1524        1.0      0          0.889
# 284          27  SUV       D      US   2315        1.0      0          0.831
# 285          27  SUV       D      US  17953        1.0      0          0.696
#
#      logit_delta  demand_instruments0   costs  profit_per_car  markups  \
# 283       -4.864               50.324   8.320          42.003    5.048
# 284       -4.174               52.115  10.061          42.054    4.180
# 285       -2.067               40.555  -5.892          46.448   -7.883
#
#      profits
# 283    0.288
# 284    0.538
# 285    4.094
