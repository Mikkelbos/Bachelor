# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from linearmodels.iv import IV2SLS
import functions as fun
import statsmodels.formula.api as sm
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('dataset.csv')
Nobs=df['ID'].count()
df['Intercept']=np.ones((Nobs,1))
df.rename(columns={'Market share':'Market_share'}, inplace=True)
df2 = df[df['Market_share'] != 0]

df2.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range        Price   HP  \
# 8    1  2021      0.010373       Aiways         U5    400   284621.700  201
# 9    1  2022      0.005976       Aiways         U5    400   313681.829  201
# 10   1  2023      0.002860       Aiways         U5    400   264524.000  201
# 21   2  2023      0.000048       Aiways         U6    405   360638.000  214
# 28   3  2019      0.040630         Audi     e-tron    375   979704.475  402
# 29   3  2020      0.034680         Audi     e-tron    375   890101.410  402
# 30   3  2021      0.010494         Audi     e-tron    375   800035.193  402
# 31   3  2022      0.017570         Audi     e-tron    375   789723.656  402
# 32   3  2023      0.001099         Audi     e-tron    375   673037.728  402
# 41   4  2021      0.003391         Audi  e-tron GT    472  1278896.110  522
# 42   4  2022      0.002090         Audi  e-tron GT    472  1287318.500  522
# 43   4  2023      0.000372         Audi  e-tron GT    472  1219342.000  522
# 52   5  2021      0.061231         Audi  Q4 e-tron    496   523778.222  281
# 53   5  2022      0.058130         Audi  Q4 e-tron    496   525536.206  281
# 54   5  2023      0.037958         Audi  Q4 e-tron    496   658553.070  281
# 65   6  2023      0.007255         Audi  Q8 e-tron    518   796974.400  335
# 66  10  2013      0.002237          BMW         I3    295   250000.000  167
# 67  10  2014      0.041751          BMW         I3    295   282999.667  167
# 68  10  2015      0.124302          BMW         I3    295   282299.667  167
# 69  10  2016      0.190756          BMW         I3    295   282300.000  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 8           34        SUV       C      CN    257        1.0
# 9           34        SUV       C      CN    183        1.0
# 10          34        SUV       C      CN    177        1.0
# 21          34        SUV       C      CN      3        1.0
# 28          17        SUV       F      DE    222        1.0
# 29          17        SUV       F      DE    491        1.0
# 30          17        SUV       F      DE    260        1.0
# 31          17        SUV       F      DE    538        1.0
# 32          17        SUV       F      DE     68        1.0
# 41          17      Sedan       F      DE     84        1.0
# 42          17      Sedan       F      DE     64        1.0
# 43          17      Sedan       F      DE     23        1.0
# 52          28        SUV       C      DE   1517        1.0
# 53          28        SUV       C      DE   1780        1.0
# 54          28        SUV       C      DE   2349        1.0
# 65          27        SUV       E      DE    449        1.0
# 66          18  Hatchback       B      DE      1        1.0
# 67          18  Hatchback       B      DE     62        1.0
# 68          18  Hatchback       B      DE    490        1.0
# 69          18  Hatchback       B      DE    227        1.0

# %%
# Copy the dataframe
data = df2.copy().reset_index(drop=True)
data.head(20)
# Out:
#     ID  Year  Market_share Manufacturer      Model  Range        Price   HP  \
# 0    1  2021      0.010373       Aiways         U5    400   284621.700  201
# 1    1  2022      0.005976       Aiways         U5    400   313681.829  201
# 2    1  2023      0.002860       Aiways         U5    400   264524.000  201
# 3    2  2023      0.000048       Aiways         U6    405   360638.000  214
# 4    3  2019      0.040630         Audi     e-tron    375   979704.475  402
# 5    3  2020      0.034680         Audi     e-tron    375   890101.410  402
# 6    3  2021      0.010494         Audi     e-tron    375   800035.193  402
# 7    3  2022      0.017570         Audi     e-tron    375   789723.656  402
# 8    3  2023      0.001099         Audi     e-tron    375   673037.728  402
# 9    4  2021      0.003391         Audi  e-tron GT    472  1278896.110  522
# 10   4  2022      0.002090         Audi  e-tron GT    472  1287318.500  522
# 11   4  2023      0.000372         Audi  e-tron GT    472  1219342.000  522
# 12   5  2021      0.061231         Audi  Q4 e-tron    496   523778.222  281
# 13   5  2022      0.058130         Audi  Q4 e-tron    496   525536.206  281
# 14   5  2023      0.037958         Audi  Q4 e-tron    496   658553.070  281
# 15   6  2023      0.007255         Audi  Q8 e-tron    518   796974.400  335
# 16  10  2013      0.002237          BMW         I3    295   250000.000  167
# 17  10  2014      0.041751          BMW         I3    295   282999.667  167
# 18  10  2015      0.124302          BMW         I3    295   282299.667  167
# 19  10  2016      0.190756          BMW         I3    295   282300.000  167
#
#     Chargetime       Type Segment Country  Sales  Intercept
# 0           34        SUV       C      CN    257        1.0
# 1           34        SUV       C      CN    183        1.0
# 2           34        SUV       C      CN    177        1.0
# 3           34        SUV       C      CN      3        1.0
# 4           17        SUV       F      DE    222        1.0
# 5           17        SUV       F      DE    491        1.0
# 6           17        SUV       F      DE    260        1.0
# 7           17        SUV       F      DE    538        1.0
# 8           17        SUV       F      DE     68        1.0
# 9           17      Sedan       F      DE     84        1.0
# 10          17      Sedan       F      DE     64        1.0
# 11          17      Sedan       F      DE     23        1.0
# 12          28        SUV       C      DE   1517        1.0
# 13          28        SUV       C      DE   1780        1.0
# 14          28        SUV       C      DE   2349        1.0
# 15          27        SUV       E      DE    449        1.0
# 16          18  Hatchback       B      DE      1        1.0
# 17          18  Hatchback       B      DE     62        1.0
# 18          18  Hatchback       B      DE    490        1.0
# 19          18  Hatchback       B      DE    227        1.0

# %%
#Scale for better intepretation

data['Price'] = data['Price']/10_000 #(Change in ms(%) for change in pris in 10.000)
data['HP'] = data['HP']/10           #(Change in ms(%) for change in HP in 10)
data['Range'] = data['Range']/10     #(Change in ms(%) for change in rækkevidde in 10)

# %%
# Creating dummy for china
data['China'] = (data['Country'] == 'CN').astype(int)

# %% [markdown]
# # IV

# %%
fun.BLP(data, 'Range')
fun.BLP(data, 'HP')
fun.BLP(data, 'Chargetime')
# Out:
#       ID  Year  Market_share Manufacturer   Model  Range      Price    HP  \
# 0      1  2021      0.010373       Aiways      U5   40.0  28.462170  20.1
# 1      1  2022      0.005976       Aiways      U5   40.0  31.368183  20.1
# 2      1  2023      0.002860       Aiways      U5   40.0  26.452400  20.1
# 3      2  2023      0.000048       Aiways      U6   40.5  36.063800  21.4
# 4      3  2019      0.040630         Audi  e-tron   37.5  97.970447  40.2
# ..   ...   ...           ...          ...     ...    ...        ...   ...
# 329  189  2023      0.000065        Volvo    EX30   47.5  36.824500  26.8
# 330  190  2021      0.014652        Volvo    XC40   45.7  46.206060  40.2
# 331  190  2022      0.033310        Volvo    XC40   45.7  41.626340  40.2
# 332  190  2023      0.031752        Volvo    XC40   45.7  43.926660  40.2
# 333  192  2023      0.000129        Voyah    Free   50.0  50.476850  48.2
#
#      Chargetime Type Segment Country  Sales  Intercept  China  Range_BLP  \
# 0            34  SUV       C      CN    257        1.0      1     2151.3
# 1            34  SUV       C      CN    183        1.0      1     3218.0
# 2            34  SUV       C      CN    177        1.0      1     4177.4
# 3            34  SUV       C      CN      3        1.0      1     4176.9
# 4            17  SUV       F      DE    222        1.0      0      580.9
# ..          ...  ...     ...     ...    ...        ...    ...        ...
# 329          28  SUV       B      SE      4        1.0      0     4169.9
# 330          28  SUV       C      SE    363        1.0      0     2145.6
# 331          28  SUV       C      SE   1020        1.0      0     3212.3
# 332          28  SUV       C      SE   1965        1.0      0     4171.7
# 333          55  SUV       E      CN      8        1.0      1     4167.4
#
#      HP_BLP  Chargetime_BLP
# 0    1358.3            1861
# 1    2033.9            2664
# 2    2640.3            3241
# 3    2639.0            3241
# 4     390.1             570
# ..      ...             ...
# 329  2633.6            3247
# 330  1338.2            1867
# 331  2013.8            2670
# 332  2620.2            3247
# 333  2612.2            3220
#
# [334 rows x 18 columns]

# %%
formula = 'np.log(Market_share) ~ 1 + [Price ~ Range_BLP + HP_BLP + Chargetime_BLP] + Range + HP + Chargetime + China '
IV = IV2SLS.from_formula(formula, data).fit(cov_type='robust')
IV.summary#.tables[1]
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            IV-2SLS Estimation Summary
# ================================================================================
# Dep. Variable:     np.log(Market_share)   R-squared:                     -5.7877
# Estimator:                      IV-2SLS   Adj. R-squared:                -5.8912
# No. Observations:                   334   F-statistic:                    28.868
# Date:                  Sun, May 12 2024   P-value (F-stat)                0.0000
# Time:                          14:26:05   Distribution:                  chi2(5)
# Cov. Estimator:                  robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -2.8041     2.3134    -1.2121     0.2255     -7.3383      1.7300
# Range          0.1995     0.0588     3.3923     0.0007      0.0842      0.3148
# HP             0.3270     0.0955     3.4228     0.0006      0.1398      0.5143
# Chargetime    -0.0848     0.0305    -2.7760     0.0055     -0.1447     -0.0249
# China         -5.4735     1.1202    -4.8862     0.0000     -7.6690     -3.2779
# Price         -0.3222     0.0761    -4.2313     0.0000     -0.4714     -0.1729
# ==============================================================================
#
# Endogenous: Price
# Instruments: Range_BLP, HP_BLP, Chargetime_BLP
# Robust Covariance (Heteroskedastic)
# Debiased: False
# """

# %% [markdown]
# # Willingness to pay

# %%
alpha = IV.params[-1] # Price coefficient
beta = IV.params[:-1]
beta_alpha_ratio = [b / -alpha for b in beta[1:]] #Willingness to pay (excluding constant)

for i in range(len(IV.params.index[1:-1])): #[1:-1] to exclude constant and price
    print('W2P:', IV.params.index[1:-1][i], beta_alpha_ratio[i])
# Out:
# W2P: Range 0.6192729655546761
# W2P: HP 1.015016128898077
# W2P: Chargetime -0.26322153555449346
# W2P: China -16.989110018549052

# %% [markdown]
# NOTE: English delimiter\
# 6,192 DKK for every 10 increase in Range\
# 10,150 DKK for every 10 increase in HP\
# -2,632 DKK for every 10 increase in Chargetime\
# -169,891 DKK for Chinese cars OR -16,989 DKK for Chinese cars???

# %% [markdown]
# # Logit

# %%
# IMPORTANT: The data must be sorted by year and ID before running the function
#             Because the CCPs returned by the function are sorted by year and ID
logit_data = data.sort_values(['Year', 'ID']).reset_index(drop=True)
X = logit_data[['Intercept', 'Range', 'HP', 'Chargetime', 'China']]
p_j = logit_data['Price']
logit_data['CCP'] = fun.ccp(alpha, beta, data, X)

# %%
logit_data[logit_data['Model'] == 'Model Y']
# Out:
#       ID  Year  Market_share Manufacturer    Model  Range     Price    HP  \
# 145  175  2021      0.061514        Tesla  Model Y   50.6  50.32390  50.6
# 222  175  2022      0.075602        Tesla  Model Y   50.6  52.11506  50.6
# 319  175  2023      0.290103        Tesla  Model Y   50.6  40.55544  50.6
#
#      Chargetime Type  ... Country  Sales  Intercept  China  Range_BLP  HP_BLP  \
# 145          27  SUV  ...      US   1524        1.0      0     2140.7  1327.8
# 222          27  SUV  ...      US   2315        1.0      0     3207.4  2003.4
# 319          27  SUV  ...      US  17953        1.0      0     4166.8  2609.8
#
#      Chargetime_BLP       CCP    Model_year       Cost
# 145            1868  0.544861  Model Y_2021  49.732602
# 222            2671  0.325551  Model Y_2022  51.125429
# 319            3248  0.675284  Model Y_2023  40.078345
#
# [3 rows x 21 columns]

# %%
probability_ratio = fun.probability_ratio(logit_data, 2013)
probability_ratio
# Out:
# Model            I3         Leaf          Zoe          Fortwo   Model S  \
# Model
# I3              1.0     9.342696     1.535961     4839.801371  0.001193
# Leaf       0.107035          1.0     0.164402      518.030468  0.000128
# Zoe        0.651058     6.082638          1.0     3150.991658  0.000777
# Fortwo     0.000207      0.00193     0.000317             1.0       0.0
# Model S  838.157302  7830.649183  1287.377214  4056514.860533       1.0
# up!        0.025265     0.236048     0.038807      122.279992   0.00003
#
# Model             up!
# Model
# I3          39.579667
# Leaf         4.236429
# Zoe         25.768661
# Fortwo       0.008178
# Model S  33173.987048
# up!               1.0

# %%
logit_data['Model_year'] = logit_data['Model'] + '_' + logit_data['Year'].astype(str)
marginal_effects = fun.marginal_effects(logit_data, IV)
marginal_effects
# Out:
#              Intercept     Range        HP Chargetime     China     Price
# Model_year
# I3_2013      -0.003335  0.000237  0.000389  -0.000101 -0.006509 -0.000383
# Leaf_2013    -0.000357  0.000025  0.000042  -0.000011 -0.000697 -0.000041
# Zoe_2013     -0.002172  0.000155  0.000253  -0.000066 -0.004239  -0.00025
# Fortwo_2013  -0.000001       0.0       0.0       -0.0 -0.000001      -0.0
# Model S_2013 -0.005942  0.000423  0.000693   -0.00018 -0.011598 -0.000683
# ...                ...       ...       ...        ...       ...       ...
# up!_2023     -0.000003       0.0       0.0       -0.0 -0.000007      -0.0
# C40_2023      -0.01158  0.000824   0.00135   -0.00035 -0.022603  -0.00133
# EX30_2023    -0.001299  0.000092  0.000151  -0.000039 -0.002536 -0.000149
# XC40_2023    -0.007346  0.000523  0.000857  -0.000222 -0.014338 -0.000844
# Free_2023    -0.000012  0.000001  0.000001       -0.0 -0.000024 -0.000001
#
# [334 rows x 6 columns]

# %%
marginal_effects[IV.params.index].mean()
# Out:
# Intercept    -0.039760
# Range         0.002829
# HP            0.004637
# Chargetime   -0.001202
# China        -0.077608
# Price        -0.004568
# dtype: float64

# %%
elasticity = fun.elasticity(logit_data, IV)
elasticity
# Out:
#              Intercept     Range         HP Chargetime    China      Price
# Model_year
# I3_2013      -2.800804  5.878661   5.454609  -1.524643     -0.0  -8.044782
# Leaf_2013    -2.803785  6.543231   4.806473  -3.646079     -0.0  -8.172212
# Zoe_2013     -2.801969  7.276622   4.378573  -4.745307     -0.0  -5.574133
# Fortwo_2013  -2.804142  2.533829   2.616101    -5.0882     -0.0  -6.780409
# Model S_2013 -0.005954  0.025801   0.046871  -0.005402     -0.0  -0.049227
# ...                ...       ...        ...        ...      ...        ...
# up!_2023     -2.804139  5.107556   2.648799  -4.070556     -0.0  -5.633317
# C40_2023     -2.792514  9.258805  13.091395  -2.364647     -0.0 -13.817402
# EX30_2023    -2.802843  9.472531   8.759877  -2.373393     -0.0 -11.858429
# XC40_2023    -2.796777  9.093849  13.111381  -2.368257     -0.0 -14.114894
# Free_2023     -2.80413  9.975665  15.761941  -4.664164 -5.47344 -16.262299
#
# [334 rows x 6 columns]

# %%
elasticity[IV.params.index].mean()
# Out:
# Intercept     -2.711790
# Range          7.534031
# HP             7.744819
# Chargetime    -2.808678
# China         -0.638151
# Price        -14.531440
# dtype: float64

# %% [markdown]
# # Cost

# %%
logit_data['Cost']=fun.cost_original(logit_data, alpha)
logit_data
# Out:
#       ID  Year  Market_share Manufacturer    Model  Range     Price    HP  \
# 0     10  2013      0.002237          BMW       I3   29.5  25.00000  16.7
# 1    132  2013      0.472036       Nissan     Leaf   32.8  25.36900  14.7
# 2    158  2013      0.205817      Renault      Zoe   36.5  17.31500  13.4
# 3    167  2013      0.002237        Smart   Fortwo   12.7  21.04575   8.0
# 4    173  2013      0.250559        Tesla  Model S   60.9  71.95631  67.5
# ..   ...   ...           ...          ...      ...    ...       ...   ...
# 329  187  2023      0.001277   Volkswagen      up!   25.6  17.48530   8.1
# 330  188  2023      0.008354        Volvo      C40   46.6  43.06649  40.2
# 331  189  2023      0.000065        Volvo     EX30   47.5  36.82450  26.8
# 332  190  2023      0.031752        Volvo     XC40   45.7  43.92666  40.2
# 333  192  2023      0.000129        Voyah     Free   50.0  50.47685  48.2
#
#      Chargetime       Type  ... Country Sales  Intercept  China  Range_BLP  \
# 0            18  Hatchback  ...      DE     1        1.0      0      168.5
# 1            43  Hatchback  ...      JP   211        1.0      0      165.2
# 2            56  Hatchback  ...      FR    92        1.0      0      161.5
# 3            60  Hatchback  ...      DE     1        1.0      0      185.3
# 4            30   Liftback  ...      US   112        1.0      0      137.1
# ..          ...        ...  ...     ...   ...        ...    ...        ...
# 329          48  Hatchback  ...      DE    79        1.0      0     4191.8
# 330          28        SUV  ...      SE   517        1.0      0     4170.8
# 331          28        SUV  ...      SE     4        1.0      0     4169.9
# 332          28        SUV  ...      SE  1965        1.0      0     4171.7
# 333          55        SUV  ...      CN     8        1.0      1     4167.4
#
#      HP_BLP  Chargetime_BLP           CCP    Model_year          Cost
# 0     111.7             237  1.190560e-03       I3_2013 -2.456078e+02
# 1     113.7             212  1.274322e-04     Leaf_2013 -2.502838e+03
# 2     115.0             199  7.751237e-04      Zoe_2013 -3.983281e+02
# 3     120.4             195  2.459936e-07   Fortwo_2013 -1.309667e+06
# 4      60.9             225  9.978766e-01  Model S_2013  7.163345e+01
# ..      ...             ...           ...           ...           ...
# 329  2652.3            3227  1.207733e-06      up!_2023 -2.667425e+05
# 330  2620.2            3247  4.146832e-03      C40_2023 -3.462530e+01
# 331  2633.6            3247  4.634532e-04     EX30_2023 -6.583371e+02
# 332  2620.2            3247  2.626512e-03     XC40_2023 -7.873594e+01
# 333  2612.2            3220  4.366509e-06     Free_2023 -7.373269e+04
#
# [334 rows x 21 columns]

# %%
logit_data[logit_data['Cost']>logit_data['Price']]
# Out:
# Empty DataFrame
# Columns: [ID, Year, Market_share, Manufacturer, Model, Range, Price, HP, Chargetime, Type, Segment, Country, Sales, Intercept, China, Range_BLP, HP_BLP, Chargetime_BLP, CCP, Model_year, Cost]
# Index: []
#
# [0 rows x 21 columns]

# %%
len(logit_data[logit_data['Cost']<0])
# Out:
# 290
